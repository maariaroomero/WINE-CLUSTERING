# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: QtAgg
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# c:\Users\romer\anaconda3\Lib\site-packages\IPython\core\magics\pylab.py:162: UserWarning: pylab import has clobbered these variables: ['boxplot']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# READ AND PROCESS URL FILE

# %%
url = "https://storage.googleapis.com/the_public_bucket/wine-clustering.csv"
data = pd.read_csv(url) 
data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %% [markdown]
# CREATE BOXPLOTS

# %%
selected_columns = ['Malic_Acid', 'Hue', 'Ash' , 'Proanthocyanins', 'OD280']
subset_data = data[selected_columns]
boxplot = subset_data.boxplot(figsize=(15, 10))

# %%
selected_columns = ['Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols']
subset_data = data[selected_columns]
boxplot = subset_data.boxplot(figsize=(15, 10))

# %%
boxplot = data.boxplot('Malic_Acid')

# %%
selected_columns = ['Alcohol', 'Ash_Alcanity']
subset_data = data[selected_columns]
boxplot = subset_data.boxplot(figsize=(15, 10))

# %%
boxplot = data.boxplot('Proline')

# %%
boxplot = data.boxplot('Magnesium')

# %%
data.describe() # No muestra la informacion de las columnas categoricas
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# CORRELATION MATRIX

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %% [markdown]
# HEATMAP

# %%
lower_left_matrix = np.tril(correlation_matrix)
mask = lower_left_matrix == 0
plt.figure(figsize=(10, 8))
sns.heatmap(lower_left_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, mask=mask)
column_names = data.columns
plt.xticks(np.arange(len(column_names)) + 0.5, column_names, rotation=45, ha='right')
plt.yticks(np.arange(len(column_names)) + 0.5, column_names, rotation=0)
plt.show()

# %% [markdown]
# SCATTERPLOTS AND HISTOGRAM

# %%
selected_columns = ['Flavanoids', 'Total_Phenols', 'Nonflavanoid_Phenols', 'Malic_Acid', 'Hue', 'Proline', 'OD280', 'Proanthocyanins']
subset_data = data[selected_columns]
sns.pairplot(data=subset_data, kind='reg', diag_kind='None', plot_kws={'line_kws': {'color': 'green'}}, corner = True)
plt.tight_layout()
plt.show()
